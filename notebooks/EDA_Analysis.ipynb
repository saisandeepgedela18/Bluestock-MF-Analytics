# %% [markdown]
# # Mutual Fund Analytics - Exploratory Data Analysis (EDA)
#
# **Intern:** Sai Sandeep Gedela
#
# **Internship:** Bluestock Fintech
#
# ## Task 3
#
# This notebook contains exploratory data analysis, visualizations, and business insights generated from the Mutual Fund Analytics datasets.

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# Load cleaned NAV history
nav = pd.read_csv("../data/processed/nav_history_clean.csv")

# Display first five rows
nav.head()
